# %% [markdown]
# <a href="https://colab.research.google.com/github/raqueldalmeida1/raqueldalmeida1/blob/main/Profissao_Cientista_de_Dados_M12_Pratique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MÓDULO 12 - Pratique**

# %% [markdown]
# Testei diferentes códigos de gráficos até chegar nesses três, onde acredito que idade, profissão e estado civil sejam mais importantes para ter um limite de crédito maior.

# %%
import pandas as pd

# %%
data = {
    'Nome': ['Alice', 'Joao', 'Charlie', 'David', 'Eva', 'Diego', 'Denize', 'Claudio'],
    'Idade': [25, 30, 35, 40, 45, 60, 22, 24],
    'Profissão': ['Engenheiro', 'Médico', 'Professor', 'Advogado', 'Médico','Engenheiro', 'Estudante','Estudante'],
    'Salário': ['4500', '8000', '5000', '10000', '12000','15000', '1200','1500'],
    'Limite_Credito': ['2500', '4000', '4000', '1000', '10000','2000', '500','250'],
    'Historico_Inadimplencia': ['0', '0', '0', '1', '0','1', '0','1'],
    'Estado_Civil': ['Casamento', 'Casamento', 'Solteiro', 'Solteiro', 'Casamento','Solteiro', 'Solteiro','Solteiro'],
    'Imovel_Proprio': ['0', '0', '0', '1', '1','1', '0','0']
}

df = pd.DataFrame(data)
df.head(5)
# Out:
#       Nome  Idade   Profissão Salário Limite_Credito Historico_Inadimplencia  \
# 0    Alice     25  Engenheiro    4500           2500                       0
# 1     Joao     30      Médico    8000           4000                       0
# 2  Charlie     35   Professor    5000           4000                       0
# 3    David     40    Advogado   10000           1000                       1
# 4      Eva     45      Médico   12000          10000                       0
#
#   Estado_Civil Imovel_Proprio
# 0    Casamento              0
# 1    Casamento              0
# 2     Solteiro              0
# 3     Solteiro              1
# 4    Casamento              1

# %%
import pandas as pd

# Definindo o dicionário com os dados fornecidos
data = {
    'Nome': ['Alice', 'Joao', 'Charlie', 'David', 'Eva', 'Diego', 'Denize', 'Claudio'],
    'Idade': [25, 30, 35, 40, 45, 60, 22, 24],
    'Profissão': ['Engenheiro', 'Médico', 'Professor', 'Advogado', 'Médico','Engenheiro', 'Estudante','Estudante'],
    'Salário': ['4500', '8000', '5000', '10000', '12000','15000', '1200','1500'],
    'Limite_Credito': ['2500', '4000', '4000', '1000', '10000','2000', '500','250'],
    'Historico_Inadimplencia': ['0', '0', '0', '1', '0','1', '0','1'],
    'Estado_Civil': ['Casamento', 'Casamento', 'Solteiro', 'Solteiro', 'Casamento','Solteiro', 'Solteiro','Solteiro'],
    'Imovel_Proprio': ['0', '0', '0', '1', '1','1', '0','0']
}

# Criando o DataFrame
df = pd.DataFrame(data)

# Convertendo colunas Salário e Limite_Credito para numérico
df['Salário'] = pd.to_numeric(df['Salário'])
df['Limite_Credito'] = pd.to_numeric(df['Limite_Credito'])

# Convertendo colunas categóricas para numéricas (Histórico_Inadimplência, Estado_Civil, Imóvel_Proprio)
df['Historico_Inadimplencia'] = pd.to_numeric(df['Historico_Inadimplencia'])
df['Imovel_Proprio'] = pd.to_numeric(df['Imovel_Proprio'])

# Verificar os dados convertidos
df.head(5)
# Out:
#       Nome  Idade   Profissão  Salário  Limite_Credito  \
# 0    Alice     25  Engenheiro     4500            2500
# 1     Joao     30      Médico     8000            4000
# 2  Charlie     35   Professor     5000            4000
# 3    David     40    Advogado    10000            1000
# 4      Eva     45      Médico    12000           10000
#
#    Historico_Inadimplencia Estado_Civil  Imovel_Proprio
# 0                        0    Casamento               0
# 1                        0    Casamento               0
# 2                        0     Solteiro               0
# 3                        1     Solteiro               1
# 4                        0    Casamento               1

# %%
# Definir limite de crédito alto como valores acima da média
media_limite = df['Limite_Credito'].mean()

# Filtrar os dados para quem tem limite de crédito alto
df_alto_credito = df[df['Limite_Credito'] > media_limite]

# Exibir o DataFrame filtrado
df_alto_credito
# Out:
#       Nome  Idade  Profissão  Salário  Limite_Credito  \
# 1     Joao     30     Médico     8000            4000
# 2  Charlie     35  Professor     5000            4000
# 4      Eva     45     Médico    12000           10000
#
#    Historico_Inadimplencia Estado_Civil  Imovel_Proprio
# 1                        0    Casamento               0
# 2                        0     Solteiro               0
# 4                        0    Casamento               1

# %%
import seaborn as sns

# Gráfico de Boxplot para Limite de Crédito por Estado Civil
plt.figure(figsize=(10,6))
sns.boxplot(x='Estado_Civil', y='Limite_Credito', data=df_alto_credito)
plt.title('Limite de Crédito por Estado Civil')
plt.xlabel('Estado Civil')
plt.ylabel('Limite de Crédito')
plt.show()

# %%
# Gráfico de Dispersão entre Idade e Limite de Crédito
plt.figure(figsize=(10,6))
plt.scatter(df_alto_credito['Idade'], df_alto_credito['Limite_Credito'])
plt.title('Relação entre Idade e Limite de Crédito Alto')
plt.xlabel('Idade')
plt.ylabel('Limite de Crédito')
plt.show()

# %%
# Gráfico de Barras para Limite de Crédito por Profissão
plt.figure(figsize=(12,6))
sns.barplot(x='Profissão', y='Limite_Credito', data=df_alto_credito)
plt.title('Limite de Crédito por Profissão')
plt.xlabel('Profissão')
plt.ylabel('Limite de Crédito')
plt.xticks(rotation=45)
plt.show()
